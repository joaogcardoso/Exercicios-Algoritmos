# %%
nome = input("Digite seu nome: ")
sobrenome = input("Digite seu sobrenome: ")

def nomeCompleto(nome, sobrenome):
    print(f"Olá, {nome} {sobrenome}! Seja bem-vindo a esse sitema!")
    
nomeCompleto(nome, sobrenome)
# Out:
# Olá, João Gabriel Souza Cardoso! Seja bem-vindo a esse sitema!

# %%
nome = input("Digite seu nome: ")
sobrenome = input("Digite seu sobrenome: ")

def nomeCompleto(nome, sobrenome):
    return f"Olá, {nome} {sobrenome}! Seja bem-vindo a esse sitema!"
    
nomeCompleto(nome, sobrenome)
# Out:
# 'Olá, João Gabriel Souza Cardoso! Seja bem-vindo a esse sitema!'
