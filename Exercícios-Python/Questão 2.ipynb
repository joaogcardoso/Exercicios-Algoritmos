# %%
nome = str(input("Digite seu nome: "))

if nome == "":
    nome = "Usuário"

def nomeCompleto(nome):
    print(f"Olá, {nome}! Seja bem-vindo a esse sitema!")
nomeCompleto(nome)
# Out:
# Olá, João Gabriel! Seja bem-vindo a esse sitema!
